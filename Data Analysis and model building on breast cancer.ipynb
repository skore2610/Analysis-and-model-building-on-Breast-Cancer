# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
data = pd.read_csv(r"C:\Users\User\Blogs\180_408_bundle_archive\data.csv")

# %%
#Checking for the dataset
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print("So the number of data points are",data.shape[0],"and columns are",data.shape[1])
# Out:
# So the number of data points are 569 and columns are 33

# %%
data.drop(columns=['Unnamed: 32'],inplace=True)

# %%
print("The columns heading are",data.columns)
# Out:
# The columns heading are Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# >From above we can say that all are float values

# %%
#checking for the duplicate values
data.drop_duplicates(subset=("id"),inplace=True)

# %%
#Checking if the values have decreased
data.shape
# Out:
# (569, 32)

# %%
data.drop(columns=['id'],inplace=True)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# >Since there are no duplicates and the id being the unique we can use the drop that column as it wont give us any data

# %%
plt.figure(figsize=(6,6))
data.mean().plot(kind='barh')

# %% [markdown]
# **From the above graph we can say that area_worst has the maximum mean**

# %%
data['diagnosis'].value_counts().plot(kind='bar')
plt.title("Values Vs type of diagnosis")
# Out:
# Text(0.5, 1.0, 'Values Vs type of diagnosis')

# %%
data['diagnosis'].value_counts().plot(kind='pie',autopct = "%1.1f%%")

# %% [markdown]
# >So from above pie chart we can say that we 62.7% as benign and 37.3% as malignant.

# %%
sns.pairplot(data.loc[:,'diagnosis':'area_mean'], hue="diagnosis")

# %% [markdown]
# >from above we can infer that texture means are having gaussian curve

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
##for result data take diagnosis column values as "0 for M('Malignant')" and "1 for B('Benign')"
data['diagnosis'] = data['diagnosis'].map({'M':0,'B':1})

# %%
##Splitting into X and y
y=data['diagnosis']
X = data.drop(columns=['diagnosis'],axis=1)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X.corr(), annot=True)

# %%
#extracting the plots which are having correlation values more than 0.8
def corr_columns(corr_matrix):
    numcolumn=list(corr_matrix.columns.values)
    b=[]
    for i in range(len(numcolumn)):
        for j in range(len(numcolumn)):
            a=[]
            if i!=j:
                if corr_matrix.iat[i,j]>0.80:
                    a.append(numcolumn[i])
                    a.append(numcolumn[j])
                    b.append(a)
    return b

# %%
#creating a list of unique values from the pair list
uniq_list = np.unique(corr_columns(data.corr()))

# %%
#Dropping the columns which are having values greater than .80
data.drop(columns=uniq_list[1:],axis=1,inplace=True)

# %%
data
# Out:
#      diagnosis  area_mean  symmetry_mean  fractal_dimension_mean  texture_se  \
# 0            0     1001.0         0.2419                 0.07871      0.9053
# 1            0     1326.0         0.1812                 0.05667      0.7339
# 2            0     1203.0         0.2069                 0.05999      0.7869
# 3            0      386.1         0.2597                 0.09744      1.1560
# 4            0     1297.0         0.1809                 0.05883      0.7813
# ..         ...        ...            ...                     ...         ...
# 564          0     1479.0         0.1726                 0.05623      1.2560
# 565          0     1261.0         0.1752                 0.05533      2.4630
# 566          0      858.1         0.1590                 0.05648      1.0750
# 567          0     1265.0         0.2397                 0.07016      1.5950
# 568          1      181.0         0.1587                 0.05884      1.4280
#
# ...

# %% [markdown]
# ## Model building

# %%
from sklearn.ensemble import RandomForestClassifier # for random forest classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm # for Support Vector Machine
from sklearn import metrics

# %%
##Splitting the model into test and train data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42, stratify=y )
print("So he number of train points are",X_train.shape[0])
print("So he number of test points are",y_test.shape[0])
# Out:
# So he number of train points are 398
# So he number of test points are 171

# %%
# Now scal the data in between 0 to 1 for prosessing
#in random forest and Xgboost scaling is not required
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) # this is normalized training data
X_test = scaler.fit_transform(X_test) # this is normalized testing data

# %%
#decision tree
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
ypred = dt.predict(X_test)
print('DECISION TREE CLASSIFIER:: ',metrics.accuracy_score(ypred,y_test))
print(metrics.confusion_matrix(y_test,ypred))
print("#"*50)

#random forest
model=RandomForestClassifier(n_estimators=100)
model.fit(X_train,y_train)# now fit our model for traiing data
prediction=model.predict(X_test)# predict for the test data
print('RANDOM FOREST CLASSIFICATION:: ',metrics.accuracy_score(prediction,y_test))
print(metrics.confusion_matrix(y_test,prediction))
print("#"*50)

#SVM
model = svm.SVC()
model.fit(X_train,y_train)# now fit our model for traiing data
prediction=model.predict(X_test)# predict for the test data
# metrics.accuracy_score(prediction,y_test)
print('SUPPORT VECTOR MACHINE:: ',metrics.accuracy_score(prediction,y_test))
print(metrics.confusion_matrix(y_test,prediction))
print("#"*50)

#knn
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train,y_train)
ypred = knn.predict(X_test)
print('K NEAREST NEIGHBOURS:: ',metrics.accuracy_score(ypred,y_test))
print(metrics.confusion_matrix(y_test,ypred))
print("#"*50)

#naive bayes
NB = GaussianNB()
NB.fit(X_train,y_train)
ypred = NB.predict(X_test)
print('NAIVE BAYES ALGORITHM:: ',metrics.accuracy_score(ypred,y_test))
print(metrics.confusion_matrix(y_test,ypred))
print("#"*50)
# Out:
# DECISION TREE CLASSIFIER::  0.9064327485380117
# [[59  5]
#  [11 96]]
# ##################################################
# RANDOM FOREST CLASSIFICATION::  0.9473684210526315
# [[ 58   6]
#  [  3 104]]
# ##################################################
# SUPPORT VECTOR MACHINE::  0.9766081871345029
# [[ 62   2]
#  [  2 105]]
# ##################################################
# K NEAREST NEIGHBOURS::  0.9532163742690059
# [[ 60   4]
#  [  4 103]]
# ##################################################
# NAIVE BAYES ALGORITHM::  0.9298245614035088
# [[ 56   8]
#  [  4 103]]
# ##################################################

# %% [markdown]
# **From above we can say that svm works the best**
# Futher we can tune the hyperparameter using randaomsearchcv or gridsearchcv
